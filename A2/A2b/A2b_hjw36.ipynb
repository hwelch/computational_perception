# %% [markdown]
# # Assignment A2b: Photon Detection
# Hunter Welch 2/18/2023

# %% [markdown]
# ## 1. Simulating a dim flash of light

# %% [markdown]
# ### 1a. Random times

# %%
from dim_flash import plotflash, randtimes

t = randtimes(10, t1=1, t2=2)
plotflash(t, t1=1, t2=2)

# %% [markdown]
# ### 1b. Random intevals

# %%
from dim_flash import plotflash, randintervals

t = randintervals(10, l=10, t1=1)
plotflash(t, t1=1, t2=2)

# %%
from dim_flash import plot_exponential_distribution

plot_exponential_distribution(10)

# %% [markdown]
# ### 1c. Seeing the flash

# %% [markdown]
# One of the main differences between the two methods above is that in the first calculation of random times, the times are independent of one another. While they are still random the times themselves do not impact each other. This is not the case for the second form of calculation, as it is necessary to take into account the previous time when considering calculation through intervals.
#
# Detecting photons within a certain interval is inherently probabilitic because the stream of photons is inheriently spontaneous. With this randomness, it introduces a probabilistic nature because it can not be completely determined through any existing method.

# %% [markdown]
# ## 2. Calculating the probability detection
#
# ### 2a. The probability of K photons

# %%
from dim_flash import poisson_pmf, plot_poisson_pmf

plot_poisson_pmf(10, 20, 0.1)

# %% [markdown]
# ### 2b. The probability of K or more photons

# %%
from dim_flash import detectionprob, plotdetectionprob

plotdetectionprob(10)
detectionprob(6, 40, 0.1)
# Out:
# 0.21486961296959495

# %% [markdown]
# ## 3. Estimating the threshold from experimental data

# %% [markdown]
# ### 3a. Simulating the photon stream

# %%
from dim_flash import lightflash, plotlightflash

plotlightflash(100)

# %% [markdown]
# ### 3b. Probability of seeing

# %%
from dim_flash import probseeing

probseeing(100)
# Out:
# 0.5543203586353891

# %% [markdown]
# ### 3c. Plotting % detected vs light intensity for different parameters

# %%
from dim_flash import plotdetectioncurve

plotdetectioncurve(a=[0.1, 0.2, 0.3], K=[3, 3, 3])
plotdetectioncurve(a=[0.1, 0.1, 0.1], K = [3, 5, 7])

# %% [markdown]
# ### 3d. Fitting parameters to experimental data

# %%
from dim_flash import plotfit

plotfit()
